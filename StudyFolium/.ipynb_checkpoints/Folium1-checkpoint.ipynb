# %% [markdown]
# # Folium 설치

# %%
#!pip3 install folium

# %%
import numpy as np
import pandas as pd
import folium

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
#한글깨짐 해결
# !pip3 install git+https://github.com/python-visualization/branca.git@master
# Out:
# Collecting git+https://github.com/python-visualization/branca.git@master
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to c:\users\tjdeh\appdata\local\temp\pip-req-build-2emmnvbi
#   Resolved https://github.com/python-visualization/branca.git to commit 52b10bd969ac25d0b70640b2eee2ea1d8e8690b3
# Requirement already satisfied: jinja2 in c:\users\tjdeh\anaconda3\lib\site-packages (from branca==0.5.0+5.g52b10bd) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tjdeh\anaconda3\lib\site-packages (from jinja2->branca==0.5.0+5.g52b10bd) (2.0.1)
#   Running command git clone -q https://github.com/python-visualization/branca.git 'C:\Users\tjdeh\AppData\Local\Temp\pip-req-build-2emmnvbi'

# %% [markdown]
# # 지도 표현

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025]
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a2b94c0125e5de4656f6aabc8594d05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a2b94c0125e5de4656f6aabc8594d05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5a2b94c0125e5de4656f6aabc8594d05 = L.map(
#                 &quot;map_5a2b94c0125e5de4656f6aabc8594d05&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19419438d1329ca7cc87e9ef8b21e2f0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5a2b94c0125e5de4656f6aabc8594d05);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('index.html')

# %% [markdown]
# # tooltip & marker

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start=10
    
)

tooltip = 'Click!'

folium.Marker(
    [33.3684955195788, 126.52918183373025],
    popup = '<strong>hello world</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c755379ed591c47636352b90016f9e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c755379ed591c47636352b90016f9e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5c755379ed591c47636352b90016f9e1 = L.map(
#                 &quot;map_5c755379ed591c47636352b90016f9e1&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f683ae23941c5bdf9dbb70500342a38 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c755379ed591c47636352b90016f9e1);
#
#
#             var marker_242c9a1173b13fa53a0b2590338242ec = L.marker(
#                 [33.3684955195788, 126.52918183373025],
#                 {}
#             ).addTo(map_5c755379ed591c47636352b90016f9e1);
#
#
#         var popup_77d881ca4f68d1ab4dea76a1b88cc9e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6021c4cf6e5871cde6808d55c08e95ce = $(`&lt;div id=&quot;html_6021c4cf6e5871cde6808d55c08e95ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello world&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_77d881ca4f68d1ab4dea76a1b88cc9e7.setContent(html_6021c4cf6e5871cde6808d55c08e95ce);
#
#
#         marker_242c9a1173b13fa53a0b2590338242ec.bindPopup(popup_77d881ca4f68d1ab4dea76a1b88cc9e7)
#         ;
#
#
#
#
#             marker_242c9a1173b13fa53a0b2590338242ec.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 마커 여러개 표시

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start=10
    
)

tooltip = 'Click!'

folium.Marker(
    [33.361593, 126.527879],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.510143, 126.491514],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip
).add_to(m)


folium.Marker(
    [33.508315, 126.541070],
    popup = '<strong>바울랩</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba5f967229ed9b124c11696d8036eb0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba5f967229ed9b124c11696d8036eb0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ba5f967229ed9b124c11696d8036eb0b = L.map(
#                 &quot;map_ba5f967229ed9b124c11696d8036eb0b&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48f122dd729b2f3d97fd0004ad532d83 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba5f967229ed9b124c11696d8036eb0b);
#
#
#             var marker_04803c599e49ede91b36b5c786d76674 = L.marker(
#                 [33.361593, 126.527879],
#                 {}
#             ).addTo(map_ba5f967229ed9b124c11696d8036eb0b);
#
#
#         var popup_dfb58fed2be6c0212c73a51ba58ce2ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f11a3f05d7d60d17019b5862af21fe72 = $(`&lt;div id=&quot;html_f11a3f05d7d60d17019b5862af21fe72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_dfb58fed2be6c0212c73a51ba58ce2ab.setContent(html_f11a3f05d7d60d17019b5862af21fe72);
#
#
#         marker_04803c599e49ede91b36b5c786d76674.bindPopup(popup_dfb58fed2be6c0212c73a51ba58ce2ab)
#         ;
#
#
#
#
#             marker_04803c599e49ede91b36b5c786d76674.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_473bd10cb2de6834eaea906e707f47df = L.marker(
#                 [33.510143, 126.491514],
#                 {}
#             ).addTo(map_ba5f967229ed9b124c11696d8036eb0b);
#
#
#         var popup_6e379cae34bff0086295579b10ba8af8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_173accc835c55575d54065d0d97f8b3a = $(`&lt;div id=&quot;html_173accc835c55575d54065d0d97f8b3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주국제공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_6e379cae34bff0086295579b10ba8af8.setContent(html_173accc835c55575d54065d0d97f8b3a);
#
#
#         marker_473bd10cb2de6834eaea906e707f47df.bindPopup(popup_6e379cae34bff0086295579b10ba8af8)
#         ;
#
#
#
#
#             marker_473bd10cb2de6834eaea906e707f47df.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_473a5401bd983d9a1456f000c122bdac = L.marker(
#                 [33.508315, 126.54107],
#                 {}
#             ).addTo(map_ba5f967229ed9b124c11696d8036eb0b);
#
#
#         var popup_cda435384cdb79d5ce17f60dda323138 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_70a4111da6fe340cfe84264337918a50 = $(`&lt;div id=&quot;html_70a4111da6fe340cfe84264337918a50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;바울랩&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_cda435384cdb79d5ce17f60dda323138.setContent(html_70a4111da6fe340cfe84264337918a50);
#
#
#         marker_473a5401bd983d9a1456f000c122bdac.bindPopup(popup_cda435384cdb79d5ce17f60dda323138)
#         ;
#
#
#
#
#             marker_473a5401bd983d9a1456f000c122bdac.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Icon

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start=10
    
)

tooltip = 'Click!'

folium.Marker(
    [33.361593, 126.527879],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='#ff0000', icon='info-sign')
).add_to(m)

folium.Marker(
    [33.510143, 126.491514],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='green', icon='bookmark')
).add_to(m)


folium.Marker(
    [33.508315, 126.541070],
    popup = '<strong>바울랩</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d24f3d3c6241f49c2ed981b28cf1eb82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d24f3d3c6241f49c2ed981b28cf1eb82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d24f3d3c6241f49c2ed981b28cf1eb82 = L.map(
#                 &quot;map_d24f3d3c6241f49c2ed981b28cf1eb82&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4bdcec3e02f41b942c5cf60d7ca2e20 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d24f3d3c6241f49c2ed981b28cf1eb82);
#
#
#             var marker_dfcbf24273c3b4b440a82dc5b4a41199 = L.marker(
#                 [33.361593, 126.527879],
#                 {}
#             ).addTo(map_d24f3d3c6241f49c2ed981b28cf1eb82);
#
#
#             var icon_c4e3aca61e6423564221653b7e2577db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;#ff0000&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dfcbf24273c3b4b440a82dc5b4a41199.setIcon(icon_c4e3aca61e6423564221653b7e2577db);
#
#
#         var popup_f1ce58d326aa40e7ae783d4f513ae50a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7bc72efc908cd4a507f9e17c367243c2 = $(`&lt;div id=&quot;html_7bc72efc908cd4a507f9e17c367243c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_f1ce58d326aa40e7ae783d4f513ae50a.setContent(html_7bc72efc908cd4a507f9e17c367243c2);
#
#
#         marker_dfcbf24273c3b4b440a82dc5b4a41199.bindPopup(popup_f1ce58d326aa40e7ae783d4f513ae50a)
#         ;
#
#
#
#
#             marker_dfcbf24273c3b4b440a82dc5b4a41199.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7a6c2594f902181f7000f91a28e74d30 = L.marker(
#                 [33.510143, 126.491514],
#                 {}
#             ).addTo(map_d24f3d3c6241f49c2ed981b28cf1eb82);
#
#
#             var icon_03c4dd746e0002947cd732c4d3695082 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a6c2594f902181f7000f91a28e74d30.setIcon(icon_03c4dd746e0002947cd732c4d3695082);
#
#
#         var popup_4a681aa80d6167edf3fafa17577494aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_15d7a3d4a527fcad0dcb133cfec9108f = $(`&lt;div id=&quot;html_15d7a3d4a527fcad0dcb133cfec9108f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주국제공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_4a681aa80d6167edf3fafa17577494aa.setContent(html_15d7a3d4a527fcad0dcb133cfec9108f);
#
#
#         marker_7a6c2594f902181f7000f91a28e74d30.bindPopup(popup_4a681aa80d6167edf3fafa17577494aa)
#         ;
#
#
#
#
#             marker_7a6c2594f902181f7000f91a28e74d30.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b46e8a9e91249cd3e066d380f31120be = L.marker(
#                 [33.508315, 126.54107],
#                 {}
#             ).addTo(map_d24f3d3c6241f49c2ed981b28cf1eb82);
#
#
#         var popup_8519db346a62a6db1bad95ffb47cebfa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d63a1f907cf40da278f484bbec875861 = $(`&lt;div id=&quot;html_d63a1f907cf40da278f484bbec875861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;바울랩&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_8519db346a62a6db1bad95ffb47cebfa.setContent(html_d63a1f907cf40da278f484bbec875861);
#
#
#         marker_b46e8a9e91249cd3e066d380f31120be.bindPopup(popup_8519db346a62a6db1bad95ffb47cebfa)
#         ;
#
#
#
#
#             marker_b46e8a9e91249cd3e066d380f31120be.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 공공데이터포털 데이터

# %%
오름 = pd.read_csv('o.csv', encoding='cp949')
오름.tail(1)
# Out:
#     읍면동  오름명                   소재지         위도        경도 주차장 화장실  표고(m)  \
# 67  중문동  법정악  제주특별자치도 서귀포시 하원동 산 1  33.258346  126.4521   Y   Y  760.1
#
#        데이터기준일자
# 67  2022-05-10

# %%
오름.isnull().sum()
# Out:
# 읍면동        0
# 오름명        0
# 소재지        0
# 위도         0
# 경도         0
# 주차장        0
# 화장실        0
# 표고(m)      0
# 데이터기준일자    0
# dtype: int64

# %%
오름[['화장실']].value_counts()
# Out:
# 화장실
# N      41
# Y      27
# dtype: int64

# %%
오름[['주차장']].value_counts()
# Out:
# 주차장
# Y      37
# N      31
# dtype: int64

# %%
오름.iloc[0]
오름.iloc[0]['오름명']
오름.iloc[0]['위도']
오름.iloc[0]['경도']
# Out:
# 126.2907797

# %%
오름.shape
# Out:
# (68, 9)

# %%
for i in range(오름.shape[0]):
    print(오름.iloc[i]['오름명'], 오름.iloc[i]['위도'], 오름.iloc[i]['경도'])
# Out:
# 송악산(절울이) 33.1994088 126.2907797
# 섯알오름 33.2042537 126.281676
# 가시오름  33.2533626 126.2490546
# 녹남봉 33.2798153 126.1954827
# 물영아리 33.3708091 126.6935196
# 머체오름 33.342895 126.6494133
# 이승이 33.342895 126.6494133
# 사려니오름 33.342895 126.6494133
# 민오름 33.3508829 126.6980129
# 운지오름 33.320538 126.7451549
# 자배봉 33.342895 126.6494133
# 생길이 33.342895 126.6494133
# 큰걸세 33.3616666 126.5291666
# 족은걸세 33.3616666 126.5291666
# 수악 33.3616666 126.5291666
# 한남리머체왓숲길 33.3305697 126.6740675
# 일출봉 33.4584473 126.9425348
# 멀미오름 33.4786495 126.8840616
# 멀미알오름 33.4786495 126.8840616
# 식산봉(바우오름) 33.4656758 126.9196473
# 큰물메(대왕수봉) 33.4398545 126.8991383
# 궁대악 33.4349078 126.8170896
# 뒤꾸부니 33.4310244 126.8273298
# 모구리오름 33.4080291 126.8271111
# 유건에오름 33.4135945 126.8467892
# 통오름 33.3944955 126.8567401
# 독자봉 33.3877114 126.8541774
# 남산봉 33.3860915 126.8081632
# 낭끼오름 33.4355716 126.842924
# 모구리알오름 33.4080291 126.8271111
# 대왕산 33.456482 126.8727771
# 군산 33.2551426 126.3683605
# 단산(바굼지오름) 33.2469709 126.3206311
# 월라봉(다래오름) 33.2442794 126.3499008
# 대병악(여진머리) 33.3066236 126.3704559
# 북오름 33.3056468 126.3313681
# 남송악(남소로기) 33.3050158 126.3046682
# 광해악(넙게오름) 33.2871076 126.3162332
# 논오름 33.2666345 126.3408035
# 금산 33.2360818 126.2870485
# 용머리 33.2340447 126.3141969
# 왕이메 33.340233 126.374785
# 따라비오름 33.3708091 126.6935196
# 대록산(큰사슴이) 33.3708091 126.6935196
# 달산봉 33.3485734 126.8327895
# 제석오름 33.3470334 126.836251
# 매봉 33.3225332 126.8228665
# 영주산 33.4048901 126.7976481
# 좌보미 33.4377473 126.7917034
# 백약이오름 33.4377473 126.7917034
# 갑선이 33.3708091 126.6935196
# 가세오름 33.3314602 126.7815087
# 토산봉 33.3223939 126.7735897
# 붉은오름 33.3708091 126.6935196
# 개오름 33.3863435 126.7997102
# 갑마장길 33.3708091 126.6935196
# 제지오름(절오름) 33.240809 126.6101421
# 월라산(도라미) 33.2705143 126.6046518
# 칡오름 33.3616666 126.5291666
# 영천오름 33.3616666 126.5291666
# 미악산(솔오름) 33.3017594 126.5573394
# 삼매봉 33.2539385 126.5595922
# 하논-보로미 33.2537823 126.5422628
# 시오름 33.3616666 126.5291666
# 고근산 33.2663637 126.5123088
# 거린사슴 33.3073127 126.4541266
# 베릿내오름 33.2514303 126.4348243
# 법정악 33.2583461 126.4521002

# %% [markdown]
# # csv 파일의 좌표에 맞게 마커표시(for문으로 구현)

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start=10
    
)

tooltip = 'Click!'

for i in range(오름.shape[0]):
    #print(오름.iloc[i]['오름명'], 오름.iloc[i]['위도'], 오름.iloc[i]['경도'])

    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f"<strong>{오름.iloc[i]['오름명']}</strong>",
        tooltip = tooltip
    ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b71af9337d5f1a9aac0d838d03b6a62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b71af9337d5f1a9aac0d838d03b6a62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1b71af9337d5f1a9aac0d838d03b6a62 = L.map(
#                 &quot;map_1b71af9337d5f1a9aac0d838d03b6a62&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cd008de8d27d0cec934e60487844cc5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b71af9337d5f1a9aac0d838d03b6a62);
#
#
#             var marker_e35c035ebdccd2c8650d1dec35b90160 = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(map_1b71af9337d5f1a9aac0d838d03b6a62);
#
#
#         var popup_b35736f3c8724fe92e17412204a35e0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5834a2b1df9ea7538cb78a664df82840 = $(`&lt;div id=&quot;html_5834a2b1df9ea7538cb78a664df82840&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_b35736f3c8724fe92e17412204a35e0d.setContent(html_5834a2b1df9ea7538cb78a664df82840);
#
#
#         marker_e35c035ebdccd2c8650d1dec35b90160.bindPopup(popup_b35736f3c8724fe92e17412204a35e0d)
#         ;
#
#
#
#
#             marker_e35c035ebdccd2c8650d1dec35b90160.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3b8081d5361b34cca6d8bbe42b973f8c = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(map_1b71af9337d5f1a9aac0d838d03b6a62);
#
#
#         var popup_28066211a4decaf51c4f91a77d4aab1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_42d0b47615340b4aff4b829b397514bd = $(`&lt;div id=&quot;html_42d0b47615340b4aff4b829b397514bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_28066211a4decaf51c4f91a77d4aab1c.setContent(html_42d0b47615340b4aff4b829b397514bd);
#
#
#         marker_3b8081d5361b34cca6d8bbe42b973f8c.bindPopup(popup_28066211a4decaf51c4f91a77d4aab1c)
#         ;
#
#
#
#
#             marker_3b8081d5361b34cca6d8bbe42b973f8c.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_adfd7e65fc7eab33af3d85664662fd4c = L.marker(
#                 [33.2533626, 126.2490546],
#                 {}
#             ).addTo(map_1b71af9337d5f1a9aac0d838d03b6a62);
#
#
#         var popup_40608ba697340af2cf4bc41cf9ee6191 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_79c56e5495f1f88653ea212d82d56de6 = $(`&lt;div id=&quot;html_79c56e5495f1f88653ea212d82d56de6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;가시오름 &lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_40608ba697340af2cf4bc41cf9ee6191.setContent(html_79c56e5495f1f88653ea212d82d56de6);
#
#
#         marker_adfd7e65fc7eab33af3d85664662fd4c.bindPopup(popup_40608ba697340af2cf4bc41cf9ee6191)
#         ;
#
#
#
#
#             marker_adfd7e65fc7eab33af3d85664662fd4c.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_953ff63046892f9b157a27d4a1064db5 = L.marker(
#                 [33.2798153, 126.1954827],
#                 {}
#             ).addTo(map_1b71af9337d5f1a9aac0d838d03b6a62);
#
#
#         var popup_70a07531bd3ca9d4efd78511f7b1010c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c292fb8f113f07d07fd904c2f21d2774 = $(`&lt;div id=&quot;html_c292fb8f113f07d07fd904c2f21d2774&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;녹남봉&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_70a07531bd3ca9d4efd78511f7b1010c.setContent(html_c292fb8f113f07d07fd904c2f21d2774);
#
#
#         marker_953ff63046892f9b157a27d4a1064db5.bindPopup(popup_70a07531bd3ca9d4efd78511f7b1010c)
#         ;
#
#
#
#
#             marker_953ff63046892f9b157a27d4a1064db5.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8b5b4bedbc0818f8c9c15edf9acab7cb = L.marker(
#                 [33.3708091, 126.6935196],
#                 {}
#             ).addTo(map_1b71af9337d5f1a9aac0d

# %% [markdown]
# # 상세 정보 표시

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start=10
    
)

tooltip = 'Click!'

for i in range(오름.shape[0]):
    #print(오름.iloc[i]['오름명'], 오름.iloc[i]['위도'], 오름.iloc[i]['경도'])

    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
        주차장 : {오름.iloc[i]["주차장"]}<br>\
        화장실: {오름.iloc[i]["화장실"]}<br>\
        </div>',
        tooltip = tooltip
    ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_580ac67219011de7c8b15017f3a64ff7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_580ac67219011de7c8b15017f3a64ff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_580ac67219011de7c8b15017f3a64ff7 = L.map(
#                 &quot;map_580ac67219011de7c8b15017f3a64ff7&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a284a0eb495b7462e4858aa237dfe4f7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_580ac67219011de7c8b15017f3a64ff7);
#
#
#             var marker_74e838a5d36ad0c3fa3e913b63e4c5b3 = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(map_580ac67219011de7c8b15017f3a64ff7);
#
#
#         var popup_a385563d5e541d54f6bbc1bb858db238 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7fe4cd0c752a3f12d68e638f6d3ae5f1 = $(`&lt;div id=&quot;html_7fe4cd0c752a3f12d68e638f6d3ae5f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실: Y&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_a385563d5e541d54f6bbc1bb858db238.setContent(html_7fe4cd0c752a3f12d68e638f6d3ae5f1);
#
#
#         marker_74e838a5d36ad0c3fa3e913b63e4c5b3.bindPopup(popup_a385563d5e541d54f6bbc1bb858db238)
#         ;
#
#
#
#
#             marker_74e838a5d36ad0c3fa3e913b63e4c5b3.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_37fcf7f1046af47f48e3b559ae788859 = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(map_580ac67219011de7c8b15017f3a64ff7);
#
#
#         var popup_64a73bbfac43a35009151bd02e1e6a24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_07b47b412770e4f4113ffb33787d2986 = $(`&lt;div id=&quot;html_07b47b412770e4f4113ffb33787d2986&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실: Y&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_64a73bbfac43a35009151bd02e1e6a24.setContent(html_07b47b412770e4f4113ffb33787d2986);
#
#
#         marker_37fcf7f1046af47f48e3b559ae788859.bindPopup(popup_64a73bbfac43a35009151bd02e1e6a24)
#         ;
#
#
#
#
#             marker_37fcf7f1046af47f48e3b559ae788859.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ffcbb748e74798048cd295346b2bb6ad = L.marker(
#                 [33.2533626, 126.2490546],
#                 {}
#             ).addTo(map_580ac67219011de7c8b15017f3a64ff7);
#
#
#         var popup_709ab218d1f71a32822f189cc17d66a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ba9483621b161a94d8fc7a444358fe8f = $(`&lt;div id=&quot;html_ba9483621b161a94d8fc7a444358fe8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;가시오름 &lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실: N&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_709ab218d1f71a32822f189cc17d66a4.setContent(html_ba9483621b161a94d8fc7a444358fe8f);
#
#
#         marker_ffcbb748e74798048cd295346b2bb6ad.bindPopup(popup_709ab218d1f71a32822f189cc17d66a4)
#         ;
#
#
#
#
#             marker_ffcbb748e74798048cd295346b2bb6ad.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0b20962becd9c09924d818ffb706c40 = L.marker(
#                 [33.2798153, 126.1954827],
#                 {}
#             ).addTo(map_580ac67219011de7c8b15017f3a64ff7);
#
#
#         var popup_392e644162795a1c947bd225cbbb80e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d934892b7086798d5fc2dc1916e65d58 = $(`&lt;div id=&quot;html_d934892b7086798d5fc2dc1916e65d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;녹남봉&lt;/strong&gt;&lt;br&gt;        주차장 : N&lt;br&gt;        화장실: N&lt;br&gt;        &lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_392e644162795a1c947bd225cbbb80e1.setContent(html_d934892b7086798d5fc2dc1916e65d58);
#
#
#         marker_b0b20962becd9c09924d818ffb706c40.b

# %%
오름['이미지'] = 오름['오름명']+'.jpg'
오름.head(1)
# Out:
#    읍면동       오름명                       소재지         위도         경도 주차장 화장실  \
# 0  대정읍  송악산(절울이)  제주특별자치도 서귀포시 대정읍 상모리 산 2  33.199409  126.29078   Y   Y
#
#    표고(m)     데이터기준일자           이미지
# 0  104.0  2022-05-10  송악산(절울이).jpg

# %% [markdown]
# # 마커에 이미지 표시

# %%
m = folium.Map(
    location=[33.3684955195788, 126.52918183373025],
    #tiles = 'Stamen Terrain',
    zoom_start=10
    
)

tooltip = 'Click!'

for i in range(오름.shape[0]):
    #print(오름.iloc[i]['오름명'], 오름.iloc[i]['위도'], 오름.iloc[i]['경도'])

    
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
        주차장 : {오름.iloc[i]["주차장"]}<br>\
        화장실: {오름.iloc[i]["화장실"]}<br>\
        <img width="80px" src="a.jpg"><br>\
        <a href="https://www.visitjeju.net/kr/search?q=%EC%98%A4%EB%A6%84#">상세페이지 이동</a></div>',
        tooltip = tooltip
    ).add_to(m)


m.save('index.html')

# %% [markdown]
# # 부트스트랩
