# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# anaconda 설치 경로 : C:\users\admin
# 현재 python과 anaconda가 동시에 설치되어 충돌위험이 있으므로
# 설치 라이브러리를 anaconda 환경으로 사용하기 위해 환경설정

# %% [markdown]
# #### 수업 시작전
# - DATABASE
#     - 도메인
#     - 테이블정의서
#     - ERD
