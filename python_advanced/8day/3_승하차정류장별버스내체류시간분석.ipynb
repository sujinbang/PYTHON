# %%
import pandas as pd

# %%
df_total=pd.DataFrame()

# %%
## 파일 불러오고 합치기
df_total=pd.DataFrame()
for i in range (1,81,1):
    file_path = './포항/trfcard({})/trfcard.csv'.format(i)
    df = pd.read_csv(file_path, encoding='utf-8-sig')
    df_total = pd.concat([df_total, df])

# %%
df_total
# Out:
#              on_date        off_date route_name                     descr  \
# 0     20200102051049  20200102051844        131            양덕-송도-시청-양학-양덕
# 1     20200102051338  20200102054549        175          문덕-고속터미널-선린병원-달전
# 2     20200102051549  20200102051930        160            문덕-대송-송도-죽도-용흥
# 3     20200102051617  20200102055046        175          문덕-고속터미널-선린병원-달전
# 4     20200102051841  20200102052310        102     문덕-남구청-고속터미널-북구보건소-양덕
# ...              ...             ...        ...                       ...
# 3870  20200328232420  20200328232628        200           양덕-남구청(야구장)-구룡포
# 3871  20200328232523  20200328233525        130  양덕-장량지구-양학-시청-송도-장량지구-양덕
# 3872  20200328232554  20200328233435        160            문덕-대송-송도-죽도-용흥
# 3873  20200328232722  20200328235259        107           문덕-시외(고속)터미널-흥해
# 3874  20200328233455  20200328234805        102     문덕-남구청-고속터미널-북구보건소-양덕
#
#      age_type trans_yn addfee_yn  start_bstop  start_gps_x  start_gps_y  \
# 0          일반        N         N        양덕차고지   129.401693    36.077258
# 1          일반        N         N        문덕사거리   129.403178    35.962298
# 2          일반        N         N        문덕사거리   129.403442    35.962846
# 3          일반        N         N       부영사랑3차   129.402520    35.973038
# 4          일반        N         N         문덕온천   129.406532    35.961964
# ...       ...      ...       ...          ...          ...          ...
# 3870       일반        N         N        형산로터리   129.368470    36.011630
# 3871       일반        N         N        북구보건소   129.379384    36.070790
# 3872       일반        N         N          북구청   129.367128    36.041941
# 3873       일반        N         N  KTX포항역(시내행)   129.342368    36.072374
# 3874       일반        Y         N       청림초등학교   129.405768    35.992544
#
#       end_bstop   end_gps_x  end_gps_y
# 0        동부초등학교  129.380866  36.062209
# 1     새마을금고해도지점  129.370626  36.015468
# 2       성우오토모티브  129.384492  35.972675
# 3           오거리  129.366312  36.031816
# 4         용덕사거리  129.415174  35.972826
# ...         ...         ...        ...
# 3870  뱃머리 평생학습원  129.354538  36.009020
# 3871      삼성쉐르빌  129.405302  36.086089
# 3872     송림초등학교  129.375650  36.029730
# 3873      SK뷰2차  129.340636  36.008334
# 3874      문덕사거리  129.402914  35.962293
#
# [842608 rows x 13 columns]

# %%
col_name = pd.read_excel('./포항/trfcard(1)/trfcard_columns.xlsx', header = 2)
col_name
# Out:
#     구분     컬럼명 (영문)     컬럼명 (한글) Not Null 여부    데이터 타입    길이 PK 정보  FK 정보  \
# 0  NaN      on_date         승차시각           Y  datetime   NaN     Y    NaN
# 1  NaN     off_date         하차시각           Y  datetime   NaN   NaN    NaN
# 2  NaN   route_name          노선명           Y   varchar   100   NaN    NaN
# 3  NaN        descr         노선설명           Y   varchar   100   NaN    NaN
# 4  NaN     age_type         승객연령           Y   varchar    20   NaN    NaN
# 5  NaN     trans_yn         환승여부           Y   varchar     1   NaN    NaN
# 6  NaN    addfee_yn       추가운임여부           Y   varchar     1   NaN    NaN
# 7  NaN  start_bstop        승차정류장           Y   varchar   100   NaN    NaN
# 8  NaN  start_gps_x  승차정류장 GPS X           Y   numeric  10,7   NaN    NaN
# 9  NaN  start_gps_y  승차정류장 GPS Y           Y   numeric  10,7   NaN    NaN
# 10 NaN    end_bstop        하차정류장           Y   varchar   100   NaN    NaN
# 11 NaN    end_gps_x  하차정류장 GPS X           Y   numeric  10,7   NaN    NaN
# 12 NaN    end_gps_y  하차정류장 GPS Y           Y   numeric  10,7   NaN    NaN
#
#     제약 조건  컬럼 설명
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# 6     NaN    NaN
# 7     NaN    NaN
# 8     NaN    NaN
# 9     NaN    NaN
# 10    NaN    NaN
# 11    NaN    NaN
# 12    NaN    NaN

# %%
kor_col = []
for j in range (len(col_name)):
    kor_col.append(col_name['컬럼명 (한글)'][j])
print(kor_col)
# Out:
# ['승차시각', '하차시각', '노선명', '노선설명', '승객연령', '환승여부', '추가운임여부', '승차정류장', '승차정류장 GPS X', '승차정류장 GPS Y', '하차정류장', '하차정류장 GPS X', '하차정류장 GPS Y']

# %%
df_total.columns = kor_col

# %%
df_total.head()
# Out:
#              승차시각            하차시각  노선명                   노선설명 승객연령 환승여부  \
# 0  20200102051049  20200102051844  131         양덕-송도-시청-양학-양덕   일반    N
# 1  20200102051338  20200102054549  175       문덕-고속터미널-선린병원-달전   일반    N
# 2  20200102051549  20200102051930  160         문덕-대송-송도-죽도-용흥   일반    N
# 3  20200102051617  20200102055046  175       문덕-고속터미널-선린병원-달전   일반    N
# 4  20200102051841  20200102052310  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
#
#   추가운임여부   승차정류장  승차정류장 GPS X  승차정류장 GPS Y      하차정류장  하차정류장 GPS X  \
# 0      N   양덕차고지   129.401693    36.077258     동부초등학교   129.380866
# 1      N   문덕사거리   129.403178    35.962298  새마을금고해도지점   129.370626
# 2      N   문덕사거리   129.403442    35.962846    성우오토모티브   129.384492
# 3      N  부영사랑3차   129.402520    35.973038        오거리   129.366312
# 4      N    문덕온천   129.406532    35.961964      용덕사거리   129.415174
#
#    하차정류장 GPS Y
# 0    36.062209
# 1    36.015468
# 2    35.972675
# 3    36.031816
# 4    35.972826

# %%
df_total['승차시각'] = df_total['승차시각'].astype(str)
df_total['하차시각'] = df_total['하차시각'].astype(str)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842608 entries, 0 to 3874
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   승차시각         842608 non-null  object
#  1   하차시각         842608 non-null  object
#  2   노선명          842608 non-null  object
#  3   노선설명         842608 non-null  object
#  4   승객연령         842608 non-null  object
#  5   환승여부         842608 non-null  object
#  6   추가운임여부       842608 non-null  object
#  7   승차정류장        842608 non-null  object
#  8   승차정류장 GPS X  842608 non-null  float64
#  9   승차정류장 GPS Y  842608 non-null  float64
#  10  하차정류장        842608 non-null  object
#  11  하차정류장 GPS X  842608 non-null  float64
#  12  하차정류장 GPS Y  842608 non-null  float64
# dtypes: float64(4), object(9)
# memory usage: 90.0+ MB

# %%
pd.to_datetime(df_total['하차시각'])
# Out:
# 0      2020-01-02 05:18:44
# 1      2020-01-02 05:45:49
# 2      2020-01-02 05:19:30
# 3      2020-01-02 05:50:46
# 4      2020-01-02 05:23:10
#                ...
# 3870   2020-03-28 23:26:28
# 3871   2020-03-28 23:35:25
# 3872   2020-03-28 23:34:35
# 3873   2020-03-28 23:52:59
# 3874   2020-03-28 23:48:05
# Name: 하차시각, Length: 842608, dtype: datetime64[ns]

# %%
df_total['소요시간'] = pd.to_datetime(df_total['하차시각']) - pd.to_datetime(df_total['승차시각'])
df_total.head()
# Out:
#              승차시각            하차시각  노선명                   노선설명 승객연령 환승여부  \
# 0  20200102051049  20200102051844  131         양덕-송도-시청-양학-양덕   일반    N
# 1  20200102051338  20200102054549  175       문덕-고속터미널-선린병원-달전   일반    N
# 2  20200102051549  20200102051930  160         문덕-대송-송도-죽도-용흥   일반    N
# 3  20200102051617  20200102055046  175       문덕-고속터미널-선린병원-달전   일반    N
# 4  20200102051841  20200102052310  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
#
#   추가운임여부   승차정류장  승차정류장 GPS X  승차정류장 GPS Y      하차정류장  하차정류장 GPS X  \
# 0      N   양덕차고지   129.401693    36.077258     동부초등학교   129.380866
# 1      N   문덕사거리   129.403178    35.962298  새마을금고해도지점   129.370626
# 2      N   문덕사거리   129.403442    35.962846    성우오토모티브   129.384492
# 3      N  부영사랑3차   129.402520    35.973038        오거리   129.366312
# 4      N    문덕온천   129.406532    35.961964      용덕사거리   129.415174
#
#    하차정류장 GPS Y            소요시간
# 0    36.062209 0 days 00:07:55
# 1    36.015468 0 days 00:32:11
# 2    35.972675 0 days 00:03:41
# 3    36.031816 0 days 00:34:29
# 4    35.972826 0 days 00:04:29

# %%
df_total.sort_values('소요시간',ascending = False)['소요시간']
# Out:
# 4499    0 days 01:29:59
# 4508    0 days 01:29:59
# 5318    0 days 01:29:59
# 2593    0 days 01:29:59
# 4834    0 days 01:29:59
#               ...
# 11025   0 days 00:00:02
# 2813    0 days 00:00:01
# 8932    0 days 00:00:01
# 15843   0 days 00:00:01
# 1577    0 days 00:00:01
# Name: 소요시간, Length: 842608, dtype: timedelta64[ns]

# %%
df_total['년(승차)'] = df_total['승차시각'].str[:4]
df_total['월(승차)'] = df_total['승차시각'].str[4:6]
df_total['일(승차)'] = df_total['승차시각'].str[6:8]
df_total['시(승차)'] = df_total['승차시각'].str[8:10]
df_total['분(승차)'] = df_total['승차시각'].str[10:12]
df_total['초(승차)'] = df_total['승차시각'].str[12:]

df_total['년(하차)'] = df_total['하차시각'].str[:4]
df_total['월(하차)'] = df_total['하차시각'].str[4:6]
df_total['일(하차)'] = df_total['하차시각'].str[6:8]
df_total['시(하차)'] = df_total['하차시각'].str[8:10]
df_total['분(하차)'] = df_total['하차시각'].str[10:12]
df_total['초(하차)'] = df_total['하차시각'].str[12:]

# %%
df_total
# Out:
#                 승차시각            하차시각  노선명                      노선설명 승객연령 환승여부  \
# 0     20200102051049  20200102051844  131            양덕-송도-시청-양학-양덕   일반    N
# 1     20200102051338  20200102054549  175          문덕-고속터미널-선린병원-달전   일반    N
# 2     20200102051549  20200102051930  160            문덕-대송-송도-죽도-용흥   일반    N
# 3     20200102051617  20200102055046  175          문덕-고속터미널-선린병원-달전   일반    N
# 4     20200102051841  20200102052310  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# ...              ...             ...  ...                       ...  ...  ...
# 3870  20200328232420  20200328232628  200           양덕-남구청(야구장)-구룡포   일반    N
# 3871  20200328232523  20200328233525  130  양덕-장량지구-양학-시청-송도-장량지구-양덕   일반    N
# 3872  20200328232554  20200328233435  160            문덕-대송-송도-죽도-용흥   일반    N
# 3873  20200328232722  20200328235259  107           문덕-시외(고속)터미널-흥해   일반    N
# 3874  20200328233455  20200328234805  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    Y
#
#      추가운임여부        승차정류장  승차정류장 GPS X  승차정류장 GPS Y  ... 일(승차)  시(승차)  분(승차)  \
# 0         N        양덕차고지   129.401693    36.077258  ...    02     05     10
# 1         N        문덕사거리   129.403178    35.962298  ...    02     05     13
# 2         N        문덕사거리   129.403442    35.962846  ...    02     05     15
# 3         N       부영사랑3차   129.402520    35.973038  ...    02     05     16
# 4         N         문덕온천   129.406532    35.961964  ...    02     05     18
# ...     ...          ...          ...          ...  ...   ...    ...    ...
# 3870      N        형산로터리   129.368470    36.011630  ...    28     23     24
# 3871      N        북구보건소   129.379384    36.070790  ...    28     23     25
# 3872      N          북구청   129.367128    36.041941  ...    28     23     25
# 3873      N  KTX포항역(시내행)   129.342368    36.072374  ...    28     23     27
# 3874      N       청림초등학교   129.405768    35.992544  ...    28     23     34
#
#      초(승차) 년(하차) 월(하차) 일(하차) 시(하차) 분(하차) 초(하차)
# 0       49  2020    01    02    05    18    44
# 1       38  2020    01    02    05    45    49
# 2       49  2020    01    02    05    19    30
# 3       17  2020    01    02    05    50    46
# 4       41  2020    01    02    05    23    10
# ...    ...   ...   ...   ...   ...   ...   ...
# 3870    20  2020    03    28    23    26    28
# 3871    23  2020    03    28    23    35    25
# 3872    54  2020    03    28    23    34    35
# 3873    22  2020    03    28    23    52    59
# 3874    55  2020    03    28    23    48    05
#
# [842608 rows x 26 columns]

# %%
df_total.columns
# Out:
# Index(['승차시각', '하차시각', '노선명', '노선설명', '승객연령', '환승여부', '추가운임여부', '승차정류장',
#        '승차정류장 GPS X', '승차정류장 GPS Y', '하차정류장', '하차정류장 GPS X', '하차정류장 GPS Y',
#        '소요시간', '년(승차)', '월(승차)', '일(승차)', '시(승차)', '분(승차)', '초(승차)', '년(하차)',
#        '월(하차)', '일(하차)', '시(하차)', '분(하차)', '초(하차)'],
#       dtype='object')

# %%
df_total['승하차정류장'] = df_total['승차정류장']+ ' - ' +df_total['하차정류장']

# %%
df_time=df_total[['승하차정류장','소요시간']].groupby('승하차정류장').sum().reset_index().sort_values('소요시간',ascending=False)
df_time
# Out:
#                     승하차정류장             소요시간
# 14059       시외버스터미널 - 죽도시장 74 days 10:26:10
# 27379        흥해환승센터 - 죽도시장 45 days 21:56:22
# 27385        흥해환승센터 - 중앙상가 33 days 14:57:33
# 21204        죽도시장 - 흥해환승센터 30 days 21:43:23
# 13820    시외버스터미널 - 구룡포환승센터 28 days 20:40:18
# ...                    ...              ...
# 1517               계원 - 계원  0 days 00:00:10
# 1049   감포진성숯불가든 - 감포진성숯불가든  0 days 00:00:10
# 16195          영보빌라 - 영보빌라  0 days 00:00:10
# 14720    안강동부터미널 - 안강동부터미널  0 days 00:00:10
# 19613           장기 - 장기파출소  0 days 00:00:06
#
# [27437 rows x 2 columns]

# %%
df_time_30 = df_time.reset_index(drop=True).head(30)
df_time_30
# Out:
#                 승하차정류장             소요시간
# 0       시외버스터미널 - 죽도시장 74 days 10:26:10
# 1        흥해환승센터 - 죽도시장 45 days 21:56:22
# 2        흥해환승센터 - 중앙상가 33 days 14:57:33
# 3        죽도시장 - 흥해환승센터 30 days 21:43:23
# 4    시외버스터미널 - 구룡포환승센터 28 days 20:40:18
# 5        두호초등학교 - 죽도시장 28 days 17:24:02
# 6      문덕사거리 - 시외버스터미널 28 days 14:04:37
# 7   구룡포근대화거리 - 시외버스터미널 28 days 08:09:51
# 8        장성초등학교 - 죽도시장 27 days 12:14:02
# 9       경북자동차학원 - 죽도시장 26 days 14:20:59
# 10        장량5단지 - 죽도시장 26 days 06:22:12
# 11         상대시장 - 죽도시장 23 days 22:26:32
# 12   구룡포환승센터 - 시외버스터미널 22 days 17:26:37
# 13        해병대서문 - 죽도시장 21 days 16:59:21
# 14    기계환승센터 - 농협포항시지부 21 days 10:03:12
# 15      죽도시장 - 구룡포환승센터 21 days 07:32:49
# 16      중앙상가 - 시외버스터미널 20 days 13:51:14
# 17        풍림아이원 - 죽도시장 20 days 10:49:56
# 18      구룡포환승센터 - 죽도시장 19 days 20:59:03
# 19     준양참마을 - 시외버스터미널 19 days 14:37:02
# 20       장성초등학교 - 중앙상가 19 days 14:32:19
# 21  KTX포항역(시내행) - 죽도시장 19 days 11:28:36
# 22     구룡포근대화거리 - 죽도시장 19 days 10:45:34
# 23        풍림아이원 - 중앙상가 19 days 10:29:53
# 24       장량휴먼시아 - 죽도시장 19 days 00:36:37
# 25     오천농협세계지점 - 죽도시장 18 days 21:52:08
# 26     환호해맞이그린빌 - 죽도시장 18 days 10:04:56
# 27   경북자동차학원 - 시외버스터미널 18 days 08:13:36
# 28       동해면사무소 - 죽도시장 18 days 04:37:03
# 29    기계환승센터 - 시외버스터미널 18 days 00:03:22

# %%
# df_time_30['소요일'] = df_time_30['소요시간'].astype('timedelta64[D]')
# df_time_30['소요시'] = df_time_30['소요시간'].astype('timedelta64[h]')
# df_time_30['소요분'] = df_time_30['소요시간'].astype('timedelta64[m]')
df_time_30['소요시간(초)'] = df_time_30['소요시간'].astype('timedelta64[s]')

# %%
df_time_30_total = df_time_30[['승하차정류장','소요시간(초)']]
df_time_30_total
# Out:
#                 승하차정류장    소요시간(초)
# 0       시외버스터미널 - 죽도시장  6431170.0
# 1        흥해환승센터 - 죽도시장  3966982.0
# 2        흥해환승센터 - 중앙상가  2905053.0
# 3        죽도시장 - 흥해환승센터  2670203.0
# 4    시외버스터미널 - 구룡포환승센터  2493618.0
# 5        두호초등학교 - 죽도시장  2481842.0
# 6      문덕사거리 - 시외버스터미널  2469877.0
# 7   구룡포근대화거리 - 시외버스터미널  2448591.0
# 8        장성초등학교 - 죽도시장  2376842.0
# 9       경북자동차학원 - 죽도시장  2298059.0
# 10        장량5단지 - 죽도시장  2269332.0
# 11         상대시장 - 죽도시장  2067992.0
# 12   구룡포환승센터 - 시외버스터미널  1963597.0
# 13        해병대서문 - 죽도시장  1875561.0
# 14    기계환승센터 - 농협포항시지부  1850592.0
# 15      죽도시장 - 구룡포환승센터  1841569.0
# 16      중앙상가 - 시외버스터미널  1777874.0
# 17        풍림아이원 - 죽도시장  1766996.0
# 18      구룡포환승센터 - 죽도시장  1717143.0
# 19     준양참마을 - 시외버스터미널  1694222.0
# 20       장성초등학교 - 중앙상가  1693939.0
# 21  KTX포항역(시내행) - 죽도시장  1682916.0
# 22     구룡포근대화거리 - 죽도시장  1680334.0
# 23        풍림아이원 - 중앙상가  1679393.0
# 24       장량휴먼시아 - 죽도시장  1643797.0
# 25     오천농협세계지점 - 죽도시장  1633928.0
# 26     환호해맞이그린빌 - 죽도시장  1591496.0
# 27   경북자동차학원 - 시외버스터미널  1584816.0
# 28       동해면사무소 - 죽도시장  1571823.0
# 29    기계환승센터 - 시외버스터미널  1555402.0

# %%
k = []
for x in range(len(df_time_30)):
    k.append(df_time_30['승하차정류장'][x])
k
# Out:
# ['시외버스터미널 - 죽도시장',
#  '흥해환승센터 - 죽도시장',
#  '흥해환승센터 - 중앙상가',
#  '죽도시장 - 흥해환승센터',
#  '시외버스터미널 - 구룡포환승센터',
#  '두호초등학교 - 죽도시장',
#  '문덕사거리 - 시외버스터미널',
#  '구룡포근대화거리 - 시외버스터미널',
#  '장성초등학교 - 죽도시장',
#  '경북자동차학원 - 죽도시장',
#  '장량5단지 - 죽도시장',
#  '상대시장 - 죽도시장',
#  '구룡포환승센터 - 시외버스터미널',
#  '해병대서문 - 죽도시장',
#  '기계환승센터 - 농협포항시지부',
#  '죽도시장 - 구룡포환승센터',
#  '중앙상가 - 시외버스터미널',
#  '풍림아이원 - 죽도시장',
#  '구룡포환승센터 - 죽도시장',
#  '준양참마을 - 시외버스터미널',
#  '장성초등학교 - 중앙상가',
#  'KTX포항역(시내행) - 죽도시장',
#  '구룡포근대화거리 - 죽도시장',
#  '풍림아이원 - 중앙상가',
#  '장량휴먼시아 - 죽도시장',
#  '오천농협세계지점 - 죽도시장',
#  '환호해맞이그린빌 - 죽도시장',
#  '경북자동차학원 - 시외버스터미널',
#  '동해면사무소 - 죽도시장',
#  '기계환승센터 - 시외버스터미널']

# %%
import matplotlib.pyplot as plt

# %%
# 그래프 크기 지정하기 = 너비, 높이
plt.rcParams['figure.figsize'] = (20, 10)
# 선의 두께 지정
plt.rcParams['lines.linewidth'] = 2
# 폰트지정
plt.rc("font", family = "Malgun Gothic", size=13)

# 데이터 넣기
df_time_30_total.plot(kind='bar')

plt.title("승객이 가장 많이 이용하는 구간 top30")
plt.ylabel("누적 승객 체류시간")

# x축 범위?
a = list(range(0,29,1))
plt.xticks([i for i in range(-1,29,1)], k, rotation = 45)

# 범례 위치 변경하기
plt.legend(loc="upper right")
# 그래프 내에 그리드선 표시하기
plt.grid(True)

plt.show()
